# %% [markdown]
# Notebook action: extracts named entities from an input text.
#
# input:
# - .csv file fcontaining the text from every document node that wants to be processed.
# - fields: node_id, text
#
# output:
# - .csv file containing all entitis extracted from each document node
# - fields: node_id, entities list. Example: [ 2180102, [ 'sap hana', 'sap ase'] ], [ 562662, [ 'sap ea designer', 'sap powerdesigner' ] ]

# %% [markdown]
# # EXECUTION PARAMETERS:

# %% [markdown]
# ### 1) Input text: (.csv format, fields: id, text)

# %%
INPUT_FOLDER = "ekg_enrichment/"
input_file = "input_5000_corpwiki_random.csv"

# %% [markdown]
# ### 2) Model to be Inferenced:

# %%
MODELS_FOLDER = 'models_saved/'
selected_model = '2021-03-22_01-22-44.checkpoint'

# %% [markdown]
# ### 3) Entity mapping table:

# %%
INPUT_FOLDER = "sap-products/"
input_file = "Final_Entity_mapping.csv"

# %% [markdown]
# # 0) IMPORT LIBRARIES

# %%
import pandas as pd  
import numpy as np
import re

# %% [markdown]
# # 1) DEFINE CLEANING FUNCTIONS:

# %%
# -------------------------------------------------------------------------
# create function to remove numbers in brackets from text_string
# -------------------------------------------------------------------------
def generate_numbers_in_brackets_list(n=200):
    numbers_list = np.arange(1,n)
    brackets_numbers_list = []
    for i in numbers_list:
        string = '[' + str(i) + ']'
        brackets_numbers_list.append(string)
    return brackets_numbers_list

# -------------------------------------------------------------------------
# create function to replace a string with another string
# -------------------------------------------------------------------------
def replace_string_from_texts_list(string, strings_list, replace_by):
    for s in strings_list:
        new_string = string.replace(s, replace_by)
    return new_string

# %%
def smart_truncate(content, length=100, suffix=''):
    if len(content) <= length:
        return content
    else:
        return ' '.join(content[:length+1].split(' ')[0:-1]) + suffix
    
def truncate(s, max_len):
    trunc1 = smart_truncate(s, length=max_len, suffix='')
    s_nlts = trunc1.strip()
    s_nlts = s_nlts.replace('     ',' ') # replace 5 spaces by 1 space
    s_nlts = s_nlts.replace('    ',' ') # replace 4 spaces by 1 space
    s_nlts = s_nlts.replace('   ',' ') # replace 3 spaces by 1 space
    s_nlts = s_nlts.replace('  ',' ') # replace 2 spaces by 1 space
#     text_sentences.append(s_nlts)
     # truncated 2
    index_trunc1 = len(trunc1)
    trunc2 = s[index_trunc1:]
    return s_nlts, trunc2

# %%
def eliminate_spaces(s):
    s_nlts = s.strip()
    s_nlts = s_nlts.replace('     ',' ') # replace 5 spaces by 1 space
    s_nlts = s_nlts.replace('    ',' ') # replace 4 spaces by 1 space
    s_nlts = s_nlts.replace('   ',' ') # replace 3 spaces by 1 space
    s_nlts = s_nlts.replace('  ',' ') # replace 2 spaces by 1 space
    return s_nlts

# %%
def split_text_string_into_sentences_v2(text_string, max_len):
    text_sentences = []
    text_sentences_tmp = text_string.split('.')
    strg_carry_forward = '' 
    
    for s_ in text_sentences_tmp:
        s = strg_carry_forward + ' ' + s_
#         print(s)
        
        nr_wrds = s.split()
        
        if len(nr_wrds) > 5:
            if len(s) <= max_len: 
#                 print(len(s), ' <= ' , max_len)
                s = eliminate_spaces(s)
                text_sentences.append(s)
                strg_carry_forward = ''
            else:
#                 print(len(s), ' > ' , max_len)
            
                counter = 1
                while len(s) > max_len:
#                     print(counter)
                    tr1, tr2 = truncate(s, max_len)
                    tr1 = eliminate_spaces(tr1)
                    text_sentences.append(tr1)

                    s = tr2
#                     print('tr1: ', tr1)
#                     print('tr2: ', tr2)
#                     print('s: ', s)
                    
                if len(s) > 0 and len(s) < max_len:
#                     print('len(s) > 0 and len(s) < max_len:')
                    nr_wrds = s.split()
                    if len(nr_wrds) > 5:
                        s = eliminate_spaces(s)
                        text_sentences.append(s)
                        strg_carry_forward = ''
                    else:
                        strg_carry_forward = s
                counter = counter + 1
        else:
#             print('s has less than 5 words')
            strg_carry_forward = s
    
    if len(strg_carry_forward) > 0:
        strg_carry_forward = eliminate_spaces(strg_carry_forward)
        text_sentences.append(strg_carry_forward)
        
    
    return text_sentences

# %%
# -------------------------------------------------------------------------
# CLEAN TEXT AND BREAK INTO SENTENCES v2.0
# -------------------------------------------------------------------------
def clean_text_string_and_break_into_sentences_v2(text_string, max_len):
    s = text_string.lower()

    s = re.sub("@\S+", " ", s)    #remove twitter account
    s = re.sub("https*\S+", " ", s)  #remove url
    s = s.replace("\t", " ")  # remove tabs
    s = s.replace("\n",". ")  # remove line-breaks

    # DELETE BEGGINING_OF_ARTICLE NUMBER STRING by DOT SPACE
    # s = "1965636085\ This must not b3 delet3d, but the number at the end yes 134411 the date of release was 23 March 2019\n2268135735\tthe following are the test cases/browser/platform combinations that were run."
    s = s.replace("\ ", " ")
    regex = re.compile(r'\d{10}')
    numbers_to_delete = regex.findall(s)
    numbers_to_delete
    for i in numbers_to_delete:
        s = s.replace(str(i), ". ")

    # DELETE VERSION NUMBERS
    # s = "sap hana 2.0 is the mew version. sap s/4hana 15.11 is the latest s4 version."                  
    regex = re.compile(r'\b\d+\.\d+\b')
    version_numbers = regex.findall(s)
    #version_numbers

    for i in version_numbers:
        s = s.replace(str(i), " ")

    # REMOVE / EXCEPT FROM IN S/4HANA
    # s = "sap hana is the in-memory database. sap s/4hana is the latest sap erp version. the test cases/browser/platform combinations that will be run"
    s = s.replace("s/4hana", "s4-hana")
    s = s.replace("s/4", "s-4")
    s = s.replace("/", " ")
    s = s.replace("s4-hana", "s4/hana")
    s = s.replace("s-4", "s/4")

    # OTHER CHARACTER REPLACEMENTS
    s = s.replace("...",". ")  # remove line-breaks
    s = s.replace(". ..",". ") # remove line-breaks
    s = s.replace(":"," ")     # remove line-breaks
    s = re.sub("#\S+", " ", s) # Remove hashtags
    s = re.sub("\'\w+", '', s) # Remove ticks and the next character

    brackets_numbers_list = generate_numbers_in_brackets_list(n=200)
    s = replace_string_from_texts_list(s, brackets_numbers_list,'')

    s = re.sub('[^A-Za-z0-9.]+', ' ', s)  # Remove all punctuations, except from .
    s = re.sub(r'\w*\d+\w*', '', s)       # Remove digits

    #replace strings
    s = s.replace("i.e", " ")  # remove i.e
    s = s.replace("run.", " ")  # remove run.
    s = s.replace(".zip", " ")  # remove .zip
    s = s.replace("server.xml", " ")  # remove server.xml
    s = s.replace(".yml", " ")  # remove .yml
    s = s.replace(".pai", " ")  # remove .pai
    s = s.replace(".xml", " ")  # remove .xml
    s = s.replace(".run", " ")  # remove .rum
    s = s.replace(".com", " ")  # remove .com

    s = re.sub('\s{2,}', " ", s)  # Replace the over spaces

    text_sentences = split_text_string_into_sentences_v2(s, max_len)
    
    return text_sentences

# %% [markdown]
# # 2) LOAD DATA

# %%
data = pd.read_csv(INPUT_FOLDER+input_file,sep=",",encoding="latin1").fillna(method='ffill')    
data.head(5)
# Out:
#      ID(n)                                     n.text             r
# 0  1474086      Screenshot 2020-05-19 at 18.55.13.png  6.223421e-07
# 1   905576                image2019-1-22_17-48-10.png  1.260983e-06
# 2  1587998  Authorization_Harmonisation_JAN_2019.pptx  2.294894e-06
# 3   491131                 image2020-9-24_9-31-29.png  2.637947e-06
# 4   368285     Screen Shot 2019-11-07 at 16.45.33.png  3.463602e-06

# %%
data.shape
# Out:
# (5000, 3)

# %%
# Changing columns name with index number
data = data.rename(columns={data.columns[0]: 'ID'})
data = data.rename(columns={data.columns[1]: 'Text'})
# data = data.rename(columns={data.columns[2]: 'R'})

# %%
data.head(5)
# Out:
#         ID                                       Text             R
# 0  1474086      Screenshot 2020-05-19 at 18.55.13.png  6.223421e-07
# 1   905576                image2019-1-22_17-48-10.png  1.260983e-06
# 2  1587998  Authorization_Harmonisation_JAN_2019.pptx  2.294894e-06
# 3   491131                 image2020-9-24_9-31-29.png  2.637947e-06
# 4   368285     Screen Shot 2019-11-07 at 16.45.33.png  3.463602e-06

# %% [markdown]
# Create a data subset: df

# %%
df = data[:1000]
df.head(5)
# Out:
#         ID                                       Text             R
# 0  1474086      Screenshot 2020-05-19 at 18.55.13.png  6.223421e-07
# 1   905576                image2019-1-22_17-48-10.png  1.260983e-06
# 2  1587998  Authorization_Harmonisation_JAN_2019.pptx  2.294894e-06
# 3   491131                 image2020-9-24_9-31-29.png  2.637947e-06
# 4   368285     Screen Shot 2019-11-07 at 16.45.33.png  3.463602e-06

# %%
df.shape
# Out:
# (1000, 3)

# %% [markdown]
# # 4) Clean data and split text into sentences

# %%
id_sentences = []
max_len = 256

for index, row in df.iterrows():
    line_id = row['ID']
    text_string = row['Text']
    text_sentences = clean_text_string_and_break_into_sentences_v2(text_string, max_len)
   
    new_line = []
    new_line.append(line_id)
    new_line.append(text_sentences)
    id_sentences.append(new_line)
    
id_sentences[:3]
# Out:
# [[1474086, ['screenshot at png']],
#  [905576, ['png']],
#  [1587998, ['authorization harmonisation jan pptx']]]

# %% [markdown]
# # 5) LOAD MODEL for Inference

# %%
# MODELS_FOLDER = 'models_saved/'
# selected_model = '2021-03-22_01-22-44.checkpoint'

# %% [markdown]
# ### Import Libraries

# %%
print('install transformers')
# !pip install --upgrade transformers==4.2.2 --quiet
# !pip install transformers[sentencepiece] --quiet #transformers v4.x -->

print('import packages')
import torch
from transformers import BertModel, BertTokenizer, BertForTokenClassification, BertConfig
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained('bert-base-cased')

import numpy as np
import pandas as pd

print('import BERT model')
from transformers import BertForTokenClassification, AdamW
model = BertForTokenClassification.from_pretrained(
    "bert-base-cased",
    #num_labels=len(tag2idx),
    num_labels= 7,
    output_attentions = False,
    output_hidden_states = False)
print('done')
# Out:
# install transformers
# import packages
# import BERT model
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertForTokenClassification: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# done

# %% [markdown]
# ### Set GPUs

# %%
# Set GPUs 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
n_gpu = torch.cuda.device_count()
torch.cuda.get_device_name(0)  
    
# Pass the model parameters to the GPU.
model.cuda();

# %% [markdown]
# ### Load model checkpoint

# %%
# selected_model = '2021-03-11_23-52-31'

PATH = MODELS_FOLDER+selected_model

# PATH = MODELS_FOLDER+selected_model+'/'+selected_model+'.checkpoint'
checkpoint = torch.load(PATH)
model.load_state_dict(checkpoint)

# # set model status
model.eval()
# # - or -
# #model.train()
# Out:
# BertForTokenClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(28996, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=7, bias=True)
# )

# %% [markdown]
# ### Get Model Parameters

# %%
# Get MOdel Parameters
param_path = PATH[:32]+'_parameters'
file_param = param_path[13:]

folder = param_path[:13]

model_name = PATH[:32]
model_name = model_name[13:]

folder, model_name, file_param
# Out:
# ('models_saved/', '2021-03-22_01-22-44', '2021-03-22_01-22-44_parameters')

# %% [markdown]
# ### LOAD tag2idx, idx2tag, tag2name from file:

# %%
selected_model
# Out:
# '2021-03-22_01-22-44.checkpoint'

# %%
# LOAD tag2idx, idx2tag, tag2name from file: 
def tag_values_tag2idx_idx2tag_tag2name_from_model(model):

    import pickle

    # tag2idx
    file = open(MODELS_FOLDER+selected_model[:19]+'_'+'tag2idx', 'rb')
    tag2idx = pickle.load(file)
    #print(tag2idx)

    # idx2tag
    file = open(MODELS_FOLDER+selected_model[:19]+'_'+'idx2tag', 'rb')
    idx2tag = pickle.load(file)
    #print(idx2tag)

    # tag2name
    file = open(MODELS_FOLDER+selected_model[:19]+'_'+'tag2name', 'rb')
    tag2name = pickle.load(file)
    #print(tag2name)
    
    tag_values = []


    for key in tag2idx.keys():
        tag_values.append(key)
        
    tags_vals = tag_values
    
    return tags_vals, tag_values, tag2idx, idx2tag, tag2name



tags_vals, tag_values, tag2idx, idx2tag, tag2name = tag_values_tag2idx_idx2tag_tag2name_from_model(selected_model)
print('tags_vals: ', tags_vals)
print('tag_values: ', tag_values)
print('tag2idx: ', tag2idx)
print('idx2tag: ', idx2tag)
print('tag2name: ', tag2name)
# Out:
# tags_vals:  ['I-PROD', 'B-PROD', 'O', 'X', '[CLS]', '[SEP]', 'PAD']
# tag_values:  ['I-PROD', 'B-PROD', 'O', 'X', '[CLS]', '[SEP]', 'PAD']
# tag2idx:  {'I-PROD': 0, 'B-PROD': 1, 'O': 2, 'X': 3, '[CLS]': 4, '[SEP]': 5, 'PAD': 6}
# idx2tag:  {0: 'I-PROD', 1: 'B-PROD', 2: 'O', 3: 'X', 4: '[CLS]', 5: '[SEP]', 6: 'PAD'}
# tag2name:  {0: 'I-PROD', 1: 'B-PROD', 2: 'O', 3: 'X', 4: '[CLS]', 5: '[SEP]', 6: 'PAD'}

# %% [markdown]
# # 6) INFERENCE MODEL

# %% [markdown]
# ## a) Define Function:

# %%
def inference_sap_bert(test_sentence, inference_model, tag2name):
    
    model = inference_model
    
    test_sentence = test_sentence.lower()

    
    tokenizer = AutoTokenizer.from_pretrained('bert-base-cased')
    tokenized_sentence = tokenizer.encode(test_sentence)
    #print('tokenized_sentence: ', tokenized_sentence)
    
    input_ids = torch.tensor([tokenized_sentence]).cuda()

    with torch.no_grad():
        output = model(input_ids)
    label_indices = np.argmax(output[0].to('cpu').numpy(), axis=2)
    #print('label_indices: ', label_indices)

    # join bpe split tokens
    tokens = tokenizer.convert_ids_to_tokens(input_ids.to('cpu').numpy()[0])
    #print('tokens: ', tokens)
    
    new_tokens, new_labels = [], []
    for token, label_idx in zip(tokens, label_indices[0]):
        if token.startswith("##"):
            new_tokens[-1] = new_tokens[-1] + token[2:]
        else:
            #new_labels.append(tag_values[label_idx])
            new_labels.append(tag2name[label_idx])
            new_tokens.append(token)

#     for token, label in zip(new_tokens, new_labels):
#         print("{}\t{}".format(label, token))
        
    prediction = {"Token": new_tokens, "Label": new_labels}
    df = pd.DataFrame(prediction)
    
    df2 = df[df['Token'] != '[CLS]']   
    prediction_df = df2[df2['Token'] != '[SEP]'] 
        
    return prediction_df

def inference_sap_bert_to_list(test_sentence, inference_model,tag2name):
    
    prediction_df = inference_sap_bert(test_sentence, inference_model,tag2name)
    prediction_list = prediction_df.values.tolist()

    return prediction_list

# %% [markdown]
# # b) Loop over NodeIDs-Text and Inference Model

# %%
tag2name = {0: 'B-PROD', 1: 'I-PROD', 2: 'O', 3: 'X', 4: '[CLS]', 5: '[SEP]', 6: 'PAD'}

# %%
def remove_o_tokens_from_token_label_list(list):
    new_list= []
    for i in list:
        if i[1] != 'O':
            new_list.append(i)
    return new_list

# %%
len(id_sentences)
# Out:
# 1000

# %% [markdown]
# ### b.1) Unit Testing:

# %%
# UNIT TESTING:
test_sentence = 'sap hana is the in-memory database from sap'

pred = inference_sap_bert_to_list(test_sentence, model,tag2name)
pred
# Out:
# [['sap', 'B-PROD'],
#  ['hana', 'I-PROD'],
#  ['is', 'O'],
#  ['the', 'O'],
#  ['in', 'O'],
#  ['-', 'O'],
#  ['memory', 'O'],
#  ['database', 'O'],
#  ['from', 'O'],
#  ['sap', 'O']]

# %%
clean_pred = remove_o_tokens_from_token_label_list(pred)
clean_pred
# Out:
# [['sap', 'B-PROD'], ['hana', 'I-PROD']]

# %%
# for row in id_sentences[:3]:
#     node_id = row[0]
#     sentces = row[1]
#     print(node_id)
#     #print(sentces)
#     for i in sentces:
#         sentces_pred = [] 
#         pred = inference_sap_bert_to_list(i, model,tag2name)
#         clean_pred = remove_o_tokens_from_token_label_list(pred)
#         print(len(clean_pred))

# %% [markdown]
# ### b.2) Real-Execution:

# %%
len(id_sentences)
# Out:
# 1000

# %%
id_predictions = []
sentces_pred = [] 
new_line= []

for row in id_sentences:
    node_id = row[0]
    sentces = row[1]
    
    # for each sentence:
    for i in sentces:
        pred = inference_sap_bert_to_list(i, model,tag2name)
        #print(pred)
        clean_pred = remove_o_tokens_from_token_label_list(pred)
        if len(clean_pred) > 0:
            sentces_pred.append(clean_pred)
        #print(sentces_pred)
        
    if len(sentces_pred) > 0:    
        new_line.append(node_id)
        new_line.append(sentces_pred)
        id_predictions.append(new_line)
    sentces_pred = [] 
    new_line= []
    
id_predictions[0]
# Out:
# [2180102,
#  [[['hanamobilepreview', 'B-PROD']],
#   [['sybase', 'B-PROD'], ['ase', 'I-PROD'], ['ase', 'I-PROD']]]]

# %%
len(id_predictions)
# Out:
# 117

# %%
def save_df_to_file(filename, df):
    file_path_to_a = 'ekg_enrichment/'+filename
    df.to_csv(file_path_to_a, sep=',',index=False)

# %%
id_pred_df = pd.DataFrame(id_predictions)

save_df_to_file('node_pred_1_1000_nodes.csv', id_pred_df)

# %%
stop
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-4f76a9dad686> in <module>
# ----> 1 stop
#
# NameError: name 'stop' is not defined

# %% [markdown]
# # 7) Consolidate Full-Entities from predictions:

# %% [markdown]
# ## a) Define function to Get entities from token/label list

# %%
def get_entities_from_token_label_list(tkn_lbl):
    prev_lbl = 'O'
    entity = ''
    entity_list = []
    sentence_entity = []
    entity_list2 = []
    space = ' '

    # tkn_lbl = [['sa', 'B-PROD']]

    for i in tkn_lbl:
        if i[1] == 'B-PROD':
            if prev_lbl == 'O' or prev_lbl == 'I-PROD':
                if entity != '':
                    entity_list.append(entity)   # append previous entity, understand it is completed
                    entity = ''

                entity = i[0]
                prev_lbl = 'B-PROD'

            elif prev_lbl == 'B-PROD':
                entity_list.append(entity)   # append previous entity, understand it is completed
                entity = ''
                
                entity = i[0]
                prev_lbl = 'B-PROD'         

        elif i[1] == 'I-PROD':
            if prev_lbl == 'B-PROD':
                tkn = i[0]
                entity = entity + space
                entity = entity + tkn
                prev_lbl = 'I-PROD'

            elif prev_lbl == 'I-PROD':
                if '##' in i[0]:
                    tkn = i[0].replace('##','')
                    entity = entity + tkn    
                    prev_lbl = 'I-PROD'
                elif '##' not in i[0]:
                    tkn = i[0].replace('##','')
                    entity = entity + space
                    entity = entity + tkn    
                    prev_lbl = 'I-PROD'
                    
            elif prev_lbl == 'O':
                if entity != '':
                    entity_list.append(entity)                 
                    entity = ''

                tkn = i[0].replace('##','')
                entity = entity + tkn 
                prev_lbl = 'I-PROD'

        elif i[1] == 'O':
            if prev_lbl == 'B-PROD' or prev_lbl == 'I-PROD':
                entity_list.append(entity)              
                entity = ''
                prev_lbl = 'O'
            elif prev_lbl == 'O':
                prev_lbl = 'O'

    if entity != '':
        entity_list.append(entity)     

    return entity_list

# %% [markdown]
# ## b) Prepare id_predictions list:

# %%
id_predictions[:5]
# Out:
# [[2180102,
#   [[['hanamobilepreview', 'B-PROD']],
#    [['sybase', 'B-PROD'], ['ase', 'I-PROD'], ['ase', 'I-PROD']]]],
#  [1562662,
#   [[['sap', 'B-PROD'],
#     ['ea', 'I-PROD'],
#     ['designer', 'I-PROD'],
#     ['powerdesigner', 'B-PROD']],
#    [['sap', 'B-PROD'],
#     ['data', 'I-PROD'],
#     ['warehouse', 'I-PROD'],
#     ['cloud', 'I-PROD'],
#     ['hana', 'B-PROD'],
#     ['hana', 'B-PROD']],
#    [['hana', 'B-PROD'],
#     ['hana', 'B-PROD'],
#     ['hana', 'B-PROD'],
#     ['sap', 'B-PROD'],
#     ['cloud', 'I-PROD'],
#     ['platform', 'I-PROD']],
#    [['sap', 'B-PROD'],
#     ['cloud', 'I-PROD'],
#     ['platform', 'I-PROD'],
#     ['hana', 'B-PROD'],
#     ['predictive', 'B-PROD'],
#     ['analytics', 'I-PROD'],
#     ['hybris', 'B-PROD'],
#     ['sap', 'B-PROD'],
#     ['bw', 'I-PROD']],
#    [['intelligent', 'B-PROD']]]],
#  [842808,
#   [[['sap', 'B-PROD'], ['marketing', 'I-PROD']],
#    [['sap', 'B-PROD'], ['marketing', 'I-PROD']],
#    [['sap', 'B-PROD'], ['marketing', 'I-PROD']]]],
#  [2517425,
#   [[['scp', 'B-PROD'], ['scp', 'B-PROD']],
#    [['cpi', 'B-PROD'], ['cloud', 'B-PROD'], ['platform', 'I-PROD']]]],
#  [1310766,
#   [[['sybase', 'B-PROD'], ['sybasegeneva', 'B-PROD']],
#    [['sybase', 'B-PROD'], ['sybase', 'B-PROD'], ['sybase', 'B-PROD']]]]]

# %%
id_predictions_cont = []
node_pred_cont = []
new_line = []

for row in id_predictions:
    node_id = row[0]
    node_pred = row[1]
    
    for sent in node_pred:
        for tkn_pred in sent:
            node_pred_cont.append(tkn_pred)
    
    new_line.append(node_id)
    new_line.append(node_pred_cont)
    
    id_predictions_cont.append(new_line)
    
    node_pred_cont = []
    new_line = []

print(len(id_predictions_cont))
id_predictions_cont[0]
# Out:
# 117
# [2180102,
#  [['hanamobilepreview', 'B-PROD'],
#   ['sybase', 'B-PROD'],
#   ['ase', 'I-PROD'],
#   ['ase', 'I-PROD']]]

# %%
id_pred_entities = []
new_line = []

for node in id_predictions_cont:
    node_id = node[0]
    pred    = node[1]
    
    node_ent = get_entities_from_token_label_list(pred)
    
    new_line.append(node_id)
    new_line.append(node_ent)
    id_pred_entities.append(new_line)
    new_line = []
    
id_pred_entities
# Out:
# [[2180102, ['hanamobilepreview', 'sybase ase ase']],
#  [1562662,
#   ['sap ea designer',
#    'powerdesigner',
#    'sap data warehouse cloud',
#    'hana',
#    'hana',
#    'hana',
#    'hana',
#    'hana',
#    'sap cloud platform',
#    'sap cloud platform',
#    'hana',
#    'predictive analytics',
#    'hybris',
#    'sap bw',
#    'intelligent']],
#  [842808, ['sap marketing', 'sap marketing', 'sap marketing']],
#  [2517425, ['scp', 'scp', 'cpi', 'cloud platform']],
#  [1310766, ['sybase', 'sybasegeneva', 'sybase', 'sybase', 'sybase']],
#  [626553, ['mira']],
#  [1263543, ['sap hana', 'netweaver']],
#  [1877764,
#   ['erp',
#    'erp',
#    'erp',
#    'kw',
#    'erp',
#    'hcm',
#    'erp',
#    'erp',
#    'erp',
#    'erp',
#    'kw',
#    'hcm',
#    'hcm',
#    'erp',
#    'hcm',
#    'erp',
#    'erp',
#    'hcm',
#    'hcm',
#    'hcm',
#    'erp']],
#  [2596248, ['cf', 'cf']],
#  [574195, ['hana', 'bw', 'hana', 'hana', 'hana', 'bw']],
#  [2042638,
#   ['bobobo',
#    'sap sybase',
#    'sybase',
#    'bobj',
#    'bobj',
#    'bobj',
#    'bobj',
#    'bobj',
#    'bobj',
#    'bobj',
#    'bobj',
#    'bobj',
#    'bobj']],
#  [1084439, ['cp']],
#  [1021200,
#   ['sap banking',
#    'sap capital yield',
#    'sap capital yield',
#    'sap erp',
#    'sap capital yield',
#    'sap erp',
#    'sap capital yield',
#    'sap capital yield',
#    'sap capital yield',
#    'sap capital yield',
#    'sap capital yield',
#    'sap capital yield',
#    'sapna']],
#  [1836268, ['hcm', 'hcm', 'hcm', 'hrpa', 'hrpa']],
#  [1643005, ['fiori']],
#  [1305560, ['hcb', 'nw']],
#  [2109303, ['cf', 'cf']],
#  [1362506, ['bw']],
#  [413736,
#   ['hana',
#    'sapcar',
#    'hana',
#    'sapcar',
#    'sapcar',
#    'sapcar',
#    'hana',
#    'hana',
#    'hana',
#    'hana',
#    'hana',
#    'sap hana',
#    'sap hana',
#    'sap hana',
#    'hana',
#    'sap hana',
#    'hana',
#    'hana',
#    'hana',
#    'hana',
#    'hana',
#    'hana',
#    'hana',
#    'hana',
#    'hana',
#    'hana',
#    'hana',
#    'hana',
#    'hana',
#    'hana',
#    'hana',
#    'hana',
#    'hana',
#    'hana',
#    'sap hana',
#    'sap hana']],
#  [1649030, ['fiori']],
#  [1165959, ['sapcpcfs', 'cf', 'cf', 'cf', 'cf']],
#  [950726,
#   ['cloud',
#    'fiori',
#    'scp',
#    'scp',
#    'cf',
#    'fiori',
#    'hana',
#    'fiori',
#    'hana',
#    'fiori',
#    'hana',
#    'hana',
#    'hana',
#    'fiori',
#    'scp',
#    'fiori',
#    'leonardo',
#    'business suite',
#    'scp',
#    'hcpcf',
#    'cf',
#    'hana',
#    'scp',
#    'hana',
#    'fiori',
#    'fiori',
#    'cf',
#    'scp',
#    'hana cloud',
#    'cf',
#    'sap business',
#    'hana',
#    'fiori',
#    'scp',
#    'sap fiori',
#    'hana',
#    'hana',
#    'scp',
#    'hana',
#    'hana',
#    'fiori']],
#  [1667965, ['sap fiori']],
#  [193629, ['scp', 'scp', 'scp']],
#  [1054645, ['nw vendor', 'nw']],
#  [1437576, ['sap fla', 'sap fla']],
#  [366559, ['sap hana']],
#  [1157237, ['cp', 'cp', 'cp']],
#  [2233011, ['hana']],
#  [503975, ['hana', 'hana', 'hana', 'hana', 'hana', 'hana', 'hana']],
#  [394741, ['hana cloud', 'fiori', 'fiori']],
#  [505625, ['hana', 'cloud']],
#  [1635691, ['fiori', 'hana', 'scp', 'business suite', 'scp']],
#  [2309891, ['sap trapp', 'saprouter', 'saprouter', 'saprouter', 'saprouter']],
#  [1089213, ['di']],
#  [515378, ['sap siebel analysis']],
#  [2176110, ['hana', 'hana', 'hana', 'hana', 'hana', 'sapid']],
#  [1065389, ['sap process governance']],
#  [598883, ['cpi']],
#  [2310677, ['hana']],
#  [1230457, ['cp', 'gateway', 'powerdesigner', 'powerdesigner']],
#  [594711,
#   ['cf',
#    'cf',
#    'cf cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf cf cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'sap enterprise messaging']],
#  [432043, ['hana', 'hana', 'hana', 'hana', 'hana']],
#  [1684842,
#   ['sap cp',
#    'sapcp',
#    'sapcp',
#    'sap cioc',
#    'nw',
#    'hana',
#    'hcm',
#    'cp',
#    'nw',
#    'hana',
#    'hcm',
#    'cp',
#    'nw',
#    'hana',
#    'hcm',
#    'cp',
#    'nw',
#    'hana',
#    'hcm',
#    'cp',
#    'nw',
#    'hana',
#    'hcm',
#    'cp',
#    'nw',
#    'hana',
#    'hcm',
#    'cp']],
#  [477909,
#   ['fiori',
#    'fiori',
#    'fiori',
#    'fiori',
#    'fiori',
#    'fiori',
#    'fiori',
#    'fiori',
#    'fiori',
#    'fiori',
#    'fiori',
#    'fiori',
#    'fiori',
#    'fiori',
#    'fiori',
#    'fiori',
#    'fiori',
#    'fiori',
#    'fiori',
#    'fiori',
#    'fiori',
#    'fiori',
#    'fiori',
#    'fiori',
#    'fiori',
#    'fiori',
#    'fiori']],
#  [995589,
#   ['hybris',
#    'hybris',
#    'hybris',
#    'hybrisds',
#    'hybris',
#    'hybris',
#    'hybris',
#    'hybris',
#    'hybris',
#    'hybris',
#    'hybris']],
#  [1603867,
#   ['sap product lifecycle management',
#    'sap product lifecycle management',
#    'sap product lifecycle management',
#    'sap product lifecycle management']],
#  [1909258, ['fiori', 'fiori', 'hana', 'fiori']],
#  [308274, ['dcp', 'dcp', 'dcp']],
#  [1692918,
#   ['cloud foundry',
#    'cloud foundry',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'sap cp',
#    'cloud platform',
#    'cf',
#    'cf',
#    'cf',
#    'hcpsr',
#    'hcpsr',
#    'cf',
#    'hcp',
#    'cf',
#    'cf',
#    'cf',
#    'hcpsr',
#    'hcpsr',
#    'cf',
#    'cf']],
#  [274407, ['hana', 'hana', 'hana']],
#  [1174257, ['cp', 'cp', 'cp']],
#  [1137261,
#   ['cp',
#    'cpea',
#    'cpea',
#    'cfs',
#    'cfs',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cpi',
#    'cfs',
#    'hana',
#    'cf',
#    'hana',
#    'cf',
#    'hana',
#    'hana ase',
#    'hana',
#    'scp',
#    'hana cf',
#    'hana']],
#  [2422423, ['fiori', 'fiori', 'fiori']],
#  [2552084,
#   ['hana cloud platform',
#    'business suite',
#    'sap business apps',
#    'hcp',
#    'hana',
#    'hana cloud platform',
#    'hcp',
#    'hana cloud platform',
#    'hana cloud platform',
#    'fiori',
#    'fiori',
#    'hcp',
#    'fiori',
#    'fiori',
#    'fiori',
#    'hcp',
#    'hcp',
#    'fiori',
#    'fiori',
#    'fiori',
#    'fiori',
#    'fiori',
#    'hcp',
#    'fiori']],
#  [228631, ['hana', 'cloud foundary', 'cloudfoundry']],
#  [1906580, ['fiori', 'fiori']],
#  [1677812, ['crm', 'bw', 'bw', 'bw', 'bw']],
#  [1270482, ['agena']],
#  [2496090, ['hcm']],
#  [243267,
#   ['sap bw',
#    'sap iq',
#    'hana',
#    'sap iq',
#    'sap iq',
#    'sap net weaver',
#    'sap iq',
#    'sap netweaver',
#    'sap iq',
#    'sap iq',
#    'sybase',
#    'sybase',
#    'sybase iq',
#    'sybase',
#    'sybase',
#    'sybase iq',
#    'sybase iq',
#    'sybase iq',
#    'sybase iq',
#    'bw',
#    'syb']],
#  [2326795, ['fiori']],
#  [363064, ['hana cloud']],
#  [223578, ['hana', 'sap cp', 'hana']],
#  [390448, ['hcm']],
#  [414290, ['hana']],
#  [704629, ['hyphens']],
#  [1758514, ['hana', 'hcm']],
#  [2524556, ['sap na']],
#  [1814406, ['cpq', 'cpq', 'cpq']],
#  [1038986, ['sap hana']],
#  [857272, ['ap', 'scp']],
#  [780643, ['cf']],
#  [679881, ['gateway', 'gateway', 'gateway', 'gateway']],
#  [1905694,
#   ['bob',
#    'hana',
#    'ase',
#    'ase',
#    'ase',
#    'hanadatalake',
#    'hanadatalke',
#    'hanadatalake',
#    'hanadatalake',
#    'cpc',
#    'hcb',
#    'scp']],
#  [501894,
#   ['cpi',
#    'cpi',
#    'kafka',
#    'kafka',
#    'kafka',
#    'cpi',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf trust',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cpi',
#    'cf',
#    'cpi',
#    'cf',
#    'cpi',
#    'cpi',
#    'cpi',
#    'cloud foundry',
#    'cf',
#    'cpi',
#    'cpi',
#    'cpi',
#    'cpi',
#    'cpi',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'kafka',
#    'cf',
#    'cf',
#    'kafka',
#    'kafka',
#    'cf',
#    'kafka',
#    'kafka',
#    'cf',
#    'kafka',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cpi',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cloud foundry',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cpiuser',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cpiuser',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cpi',
#    'cf',
#    'cf',
#    'cf',
#    'cpi',
#    'cpi',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'sap hana',
#    'cpi',
#    'sap hana',
#    'cpi',
#    'cf',
#    'cf',
#    'cf',
#    'cpea',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cloudops',
#    'cpi',
#    'cloudops',
#    'cpi',
#    'cpi',
#    'cpi',
#    'cf',
#    'cpi',
#    'cpi',
#    'cpi',
#    'cf',
#    'cpi',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'cf',
#    'sap hana',
#    'hana',
#    'cf',
#    'sap hana',
#    'cf',
#    'cf',
#    'cf',
#    'sap hana',
#    'hana',
#    'cf',
#    'sap hana',
#    'sap hana',
#    'hana',
#    'cf',
#    'cpi',
#    'cf',
#    'cpi',
#    'cf',
#    'cpi',
#    'cpi',
#    'cf',
#    'cf']],
#  [185319, ['sap mcm']],
#  [1608202, ['cpi', 'hana']],
#  [1880525, ['hana', 'hana', 'hana', 'hana']],
#  [2014314,
#   ['lumira',
#    'lumira',
#    'lumira',
#    'hana',
#    'hana',
#    'hana',
#    'hana employee network',
#    'sap hana',
#    'lumira']],
#  [2084651, ['hybris', 'hybris', 'hybris', 'hybris']],
#  [304099, ['businessobjects', 'businessobjects', 'businessobjects']],
#  [2237905, ['hcp']],
#  [1354743, ['sap innovative business solutions', 'sap enterprise threat']],
#  [1133311, ['scp']],
#  [1077629,
#   ['sap id',
#    'sap id',
#    'sap id',
#    'hana cloud platform',
#    'lumira',
#    'lumira',
#    'sap bi',
#    'sapid',
#    'cloudlumira',
#    'bobobo']],
#  [1868797, ['sardegna', 'sardegna']],
#  [1676969, ['harvard']],
#  [2584591,
#   ['cf',
#    'sap hana',
#    'sap hana',
#    'sap cf',
#    'cloudfoundry',
#    'hana',
#    'cloudfoundry',
#    'hana',
#    'hana',
#    'sap cloud platform',
#    'cf',
#    'cf',
#    'cf',
#    'hana',
#    'cf',
#    'hana',
#    'cf',
#    'cf',
#    'cf',
#    'hana',
#    'hana',
#    'cf',
#    'hana']],
#  [464723, ['nw', 'nw']],
#  [1413714, ['suite', 'cp', 'cp', 'cp', 'cp', 'cp']],
#  [1637082, ['hana']],
#  [1239564, ['sap crm']],
#  [304574, ['caf']],
#  [2498886,
#   ['netweaver',
#    'netweaver',
#    'netweaver',
#    'netweaver',
#    'netweaver',
#    'icm',
#    'icm',
#    'sap netweaver',
#    'sap web dispacther',
#    'sap web dispatcher',
#    'sap security core']],
#  [2422558, ['gateway', 'gateway', 'gateway', 'gateway', 'fiori']],
#  [586396, ['hana', 'bw', 'hana']],
#  [1130714, ['cf', 'hana', 'cf']],
#  [692429, ['cloud foundry', 'cloud foundry', 'cf', 'cf', 'cf']],
#  [2010958, ['bw']],
#  [1034974, ['cfp', 'cfp cfp']],
#  [1871748, ['hcm']],
#  [1896666, ['hana', 'sap iq', 'hana', 'hana', 'hana', 'hana', 'hana', 'hana']],
#  [1933102, ['hcpbd']],
#  [319272, ['sybase']],
#  [413773, ['sap monsoon']],
#  [522167, ['bobox']],
#  [206309, ['sap netweaver']],
#  [1559970, ['sap eso eso', 'sap eso']],
#  [456834, ['businessobjects']],
#  [1476754, ['dcp']],
#  [1883649, ['hana cloud platform']],
#  [2526179, ['nw']],
#  [979324, ['cpi']],
#  [2140164, ['hana', 'hana', 'hana']],
#  [1879723, ['hana']],
#  [1913875, ['hanalytics']]]

# %% [markdown]
# # MAP FINAL ENTITIES:

# %%
id_pred_entities[:3]
# Out:
# [[2180102, ['hanamobilepreview', 'sybase ase ase']],
#  [1562662,
#   ['sap ea designer',
#    'powerdesigner',
#    'sap data warehouse cloud',
#    'hana',
#    'hana',
#    'hana',
#    'hana',
#    'hana',
#    'sap cloud platform',
#    'sap cloud platform',
#    'hana',
#    'predictive analytics',
#    'hybris',
#    'sap bw',
#    'intelligent']],
#  [842808, ['sap marketing', 'sap marketing', 'sap marketing']]]

# %% [markdown]
# ### Load Entity mapping table:

# %%
# INPUT_FOLDER = "sap-products/"
# input_file = "Final_Entity_mapping.csv"

# %%
df_ent_map = pd.read_csv(INPUT_FOLDER+input_file,sep=",",encoding="latin1").fillna(method='ffill')    
df_ent_map.head(5)
# Out:
#                                      Source  \
# 0                     sap 365 messaging hub
# 1                  sap 3d visual enterprise
# 2                                   sap a1s
# 3  sap accelerated trade promotion planning
# 4                         sap accelerometer
#
#                                      Target
# 0                     sap 365 messaging hub
# 1                  sap 3d visual enterprise
# 2                                   sap a1s
# 3  sap accelerated trade promotion planning
# 4                         sap accelerometer

# %%
list_ent_map = df_ent_map.values.tolist()

# %%
print(list_ent_map)
# Out:
# [['sap 365 messaging hub', 'sap 365 messaging hub'], ['sap 3d visual enterprise', 'sap 3d visual enterprise'], ['sap a1s', 'sap a1s'], ['sap accelerated trade promotion planning', 'sap accelerated trade promotion planning'], ['sap accelerometer', 'sap accelerometer'], ['sap access control', 'sap access control'], ['sap access violation management', 'sap access violation management'], ['sap account intelligence', 'sap account intelligence'], ['sap account substantiation and automation', 'sap account substantiation and automation'], ['sap accounting doc approve', 'sap accounting doc approve'], ['sap accounts payable', 'sap accounts payable'], ['sap accpak for data srvs', 'sap accpak for data srvs'], ['sap accpak inf steward', 'sap accpak inf steward'], ['sap acrobat connect', 'sap acrobat connect'], ['sap acs for sap s/4hana', 'sap acs for sap s/4hana'], ['sap act', 'sap act'], ['sap ada cloud etd', 'sap ada cloud etd'], ['sap adapter for quality center', 'sap adapter for quality center'], ['sap adapters for pi', 'sap adapters for pi'], ['sap adaptive server enterprise', 'sap adaptive server enterprise'], ['sap add-on assembly kit', 'sap add-on assembly kit'], ['sap add-on f sap sol', 'sap add-on f sap sol'], ['sap add-on f srm', 'sap add-on f srm'], ['sap adm cloud edition', 'sap adm cloud edition'], ['sap ads', 'sap ads'], ['sap advanced data migration', 'sap advanced data migration'], ['sap advanced planning and optimization', 'sap advanced planning and optimization'], ['sap advanced track and trace ', 'sap advanced track and trace '], ['sap advantage database server', 'sap advantage database server'], ['sap aerospace & defense', 'sap aerospace & defense'], ['sap afaria', 'sap afaria'], ['sap aged care management', 'sap aged care management'], ['sap agent connection', 'sap agent connection'], ['sap agent performance management', 'sap agent performance management'], ['sap agile data preparation', 'sap agile data preparation'], ['sap agricultural contract management', 'sap agricultural contract management'], ['sap ai core', 'sap ai core'], ['sap ai foundation', 'sap ai foundation'], ['sap all-in-one access kit', 'sap all-in-one access kit'], ['sap all-in-one manufacturing', 'sap all-in-one manufacturing'], ['sap allegiance', 'sap allegiance'], ['sap allocation and rescheduling optimization', 'sap allocation and rescheduling optimization'], ['sap altiscale data cloud', 'sap altiscale data cloud'], ['sap analysis for microsoft office', 'sap analysis for microsoft office'], ['sap analytic apps', 'sap analytic apps'], ['sap analytical services', 'sap analytical services'], ['sap analytics cloud', 'sap analytics cloud'], ['sap analytics extension directory', 'sap analytics extension directory'], ['sap analytics extn directory', 'sap analytics extn directory'], ['sap analytics foundation', 'sap analytics foundation'], ['sap analytics hub', 'sap analytics hub'], ['sap anywhere', 'sap anywhere'], ['sap ap add-on', 'sap ap add-on'], ['sap api business hub', 'sap api business hub'], ['sap api management', 'sap api management'], ['sap apo', 'sap apo'], ['sap appcenter', 'sap appcenter'], ['sap apparel and footwear', 'sap apparel and footwear'], ['sap application intelligence', 'sap application intelligence'], ['sap application interface framework', 'sap application interface framework'], ['sap application visualization', 'sap application visualization'], ['sap approve all', 'sap approve all'], ['sap ar service technician', 'sap ar service technician'], ['sap ar warehouse picker', 'sap ar warehouse picker'], ['sap archiving and document access', 'sap archiving and document access'], ['sap ariba cloud integration gateway', 'sap ariba cloud integration gateway'], ['sap ariba process mining', 'sap ariba process mining'], ['sap ariba procurement', 'sap ariba procurement'], ['sap aro', 'sap aro'], ['sap ase', 'sap ase'], ['sap assessment management', 'sap assessment management'], ['sap asset information workbench', 'sap asset information workbe ...

# %% [markdown]
# ### Map Entities

# %% [markdown]
# #### a) Define function:

# %%
# UNIT TESTING:
entity_in = 'hana'

ent_mapping = df_ent_map.loc[df_ent_map['Source'] == entity_in]
entity_out = ent_mapping.iloc[0]['Target']
entity_out
# Out:
# 'sap hana'

# %%
def entity_in_entity_out(entity_in):
    ent_mapping = df_ent_map.loc[df_ent_map['Source'] == entity_in]
    if len(ent_mapping) > 0:
        ent_out = ent_mapping.iloc[0]['Target']
    entity_out = ent_out
    return entity_out

# %%
entity_in = 'hana'
entity_in_entity_out(entity_in)
# Out:
# 'sap hana'

# %% [markdown]
# #### b) Execute Entity Mapping:

# %%
final_id_entities = []
final_row_ent = []
final_row = []

for row in id_pred_entities:
    nodeid = row[0]
    entities = row[1]
    
    for entity_in in entities:
#         entity_out = entity_in_entity_out(entity_in)
#         if len(entity_out) > 0:
        ent_mapping = df_ent_map.loc[df_ent_map['Source'] == entity_in]
        if len(ent_mapping) > 0:
            entity_out = ent_mapping.iloc[0]['Target']
            final_row_ent.append(entity_out)
     
    final_row.append(nodeid)
    final_row.append(final_row_ent)
    final_id_entities.append(final_row)
    
    final_row_ent = []
    final_row = []

# %%
len(final_id_entities)
final_id_entities
# Out:
# [[2180102, ['sap hana', 'sap ase']],
#  [1562662,
#   ['sap ea designer',
#    'sap powerdesigner',
#    'sap data warehouse cloud',
#    'sap hana',
#    'sap hana',
#    'sap hana',
#    'sap hana',
#    'sap hana',
#    'sap cloud platform',
#    'sap cloud platform',
#    'sap hana',
#    'sap predictive analytics',
#    'sap hybris']],
#  [842808, ['sap marketing', 'sap marketing', 'sap marketing']],
#  [2517425, ['sap cloud platform integration', 'sap cloud platform']],
#  [1310766,
#   ['sap sybase iq', 'sap sybase iq', 'sap sybase iq', 'sap sybase iq']],
#  [626553, []],
#  [1263543, ['sap hana', 'sap netweaver']],
#  [1877764,
#   ['sap erp',
#    'sap erp',
#    'sap erp',
#    'sap knowledge warehouse',
#    'sap erp',
#    'sap hcm',
#    'sap erp',
#    'sap erp',
#    'sap erp',
#    'sap erp',
#    'sap knowledge warehouse',
#    'sap hcm',
#    'sap hcm',
#    'sap erp',
#    'sap hcm',
#    'sap erp',
#    'sap erp',
#    'sap hcm',
#    'sap hcm',
#    'sap hcm',
#    'sap erp']],
#  [2596248, ['sap cloud foundry', 'sap cloud foundry']],
#  [574195,
#   ['sap hana',
#    'sap business warehouse',
#    'sap hana',
#    'sap hana',
#    'sap hana',
#    'sap business warehouse']],
#  [2042638,
#   ['sap sybase iq',
#    'sap business objects',
#    'sap business objects',
#    'sap business objects',
#    'sap business objects',
#    'sap business objects',
#    'sap business objects',
#    'sap business objects',
#    'sap business objects',
#    'sap business objects',
#    'sap business objects']],
#  [1084439, ['sap cloud platform']],
#  [1021200,
#   ['sap banking',
#    'sap capital yield',
#    'sap capital yield',
#    'sap erp',
#    'sap capital yield',
#    'sap erp',
#    'sap capital yield',
#    'sap capital yield',
#    'sap capital yield',
#    'sap capital yield',
#    'sap capital yield',
#    'sap capital yield']],
#  [1836268, ['sap hcm', 'sap hcm', 'sap hcm']],
#  [1643005, ['sap fiori']],
#  [1305560, ['sap netweaver']],
#  [2109303, ['sap cloud foundry', 'sap cloud foundry']],
#  [1362506, ['sap business warehouse']],
#  [413736,
#   ['sap hana',
#    'sap car',
#    'sap hana',
#    'sap car',
#    'sap car',
#    'sap car',
#    'sap hana',
#    'sap hana',
#    'sap hana',
#    'sap hana',
#    'sap hana',
#    'sap hana',
#    'sap hana',
#    'sap hana',
#    'sap hana',
#    'sap hana',
#    'sap hana',
#    'sap hana',
#    'sap hana',
#    'sap hana',
#    'sap hana',
#    'sap hana',
#    'sap hana',
#    'sap hana',
#    'sap hana',
#    'sap hana',
#    'sap hana',
#    'sap hana',
#    'sap hana',
#    'sap hana',
#    'sap hana',
#    'sap hana',
#    'sap hana',
#    'sap hana',
#    'sap hana',
#    'sap hana']],
#  [1649030, ['sap fiori']],
#  [1165959,
#   ['sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry']],
#  [950726,
#   ['sap fiori',
#    'sap cloud foundry',
#    'sap fiori',
#    'sap hana',
#    'sap fiori',
#    'sap hana',
#    'sap fiori',
#    'sap hana',
#    'sap hana',
#    'sap hana',
#    'sap fiori',
#    'sap fiori',
#    'sap leonardo',
#    'sap business suite',
#    'sap cloud foundry',
#    'sap hana',
#    'sap hana',
#    'sap fiori',
#    'sap fiori',
#    'sap cloud foundry',
#    'sap hana cloud',
#    'sap cloud foundry',
#    'sap hana',
#    'sap fiori',
#    'sap fiori',
#    'sap hana',
#    'sap hana',
#    'sap hana',
#    'sap hana',
#    'sap fiori']],
#  [1667965, ['sap fiori']],
#  [193629, []],
#  [1054645, ['sap netweaver']],
#  [1437576, []],
#  [366559, ['sap hana']],
#  [1157237, ['sap cloud platform', 'sap cloud platform', 'sap cloud platform']],
#  [2233011, ['sap hana']],
#  [503975,
#   ['sap hana',
#    'sap hana',
#    'sap hana',
#    'sap hana',
#    'sap hana',
#    'sap hana',
#    'sap hana']],
#  [394741, ['sap hana cloud', 'sap fiori', 'sap fiori']],
#  [505625, ['sap hana']],
#  [1635691, ['sap fiori', 'sap hana', 'sap business suite']],
#  [2309891, []],
#  [1089213, []],
#  [515378, []],
#  [2176110, ['sap hana', 'sap hana', 'sap hana', 'sap hana', 'sap hana']],
#  [1065389, []],
#  [598883, ['sap cloud platform integration']],
#  [2310677, ['sap hana']],
#  [1230457,
#   ['sap cloud platform',
#    'sap gateway',
#    'sap powerdesigner',
#    'sap powerdesigner']],
#  [594711,
#   ['sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry']],
#  [432043, ['sap hana', 'sap hana', 'sap hana', 'sap hana', 'sap hana']],
#  [1684842,
#   ['sap cloud platform',
#    'sap cloud platform',
#    'sap cloud platform',
#    'sap netweaver',
#    'sap hana',
#    'sap hcm',
#    'sap cloud platform',
#    'sap netweaver',
#    'sap hana',
#    'sap hcm',
#    'sap cloud platform',
#    'sap netweaver',
#    'sap hana',
#    'sap hcm',
#    'sap cloud platform',
#    'sap netweaver',
#    'sap hana',
#    'sap hcm',
#    'sap cloud platform',
#    'sap netweaver',
#    'sap hana',
#    'sap hcm',
#    'sap cloud platform',
#    'sap netweaver',
#    'sap hana',
#    'sap hcm',
#    'sap cloud platform']],
#  [477909,
#   ['sap fiori',
#    'sap fiori',
#    'sap fiori',
#    'sap fiori',
#    'sap fiori',
#    'sap fiori',
#    'sap fiori',
#    'sap fiori',
#    'sap fiori',
#    'sap fiori',
#    'sap fiori',
#    'sap fiori',
#    'sap fiori',
#    'sap fiori',
#    'sap fiori',
#    'sap fiori',
#    'sap fiori',
#    'sap fiori',
#    'sap fiori',
#    'sap fiori',
#    'sap fiori',
#    'sap fiori',
#    'sap fiori',
#    'sap fiori',
#    'sap fiori',
#    'sap fiori',
#    'sap fiori']],
#  [995589,
#   ['sap hybris',
#    'sap hybris',
#    'sap hybris',
#    'sap hybris',
#    'sap hybris',
#    'sap hybris',
#    'sap hybris',
#    'sap hybris',
#    'sap hybris',
#    'sap hybris']],
#  [1603867,
#   ['sap product lifecycle management',
#    'sap product lifecycle management',
#    'sap product lifecycle management',
#    'sap product lifecycle management']],
#  [1909258, ['sap fiori', 'sap fiori', 'sap hana', 'sap fiori']],
#  [308274, []],
#  [1692918,
#   ['sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud platform',
#    'sap cloud platform',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap hana cloud platform',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry']],
#  [274407, ['sap hana', 'sap hana', 'sap hana']],
#  [1174257, ['sap cloud platform', 'sap cloud platform', 'sap cloud platform']],
#  [1137261,
#   ['sap cloud platform',
#    'sap cloud platform',
#    'sap cloud platform',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud platform integration',
#    'sap hana',
#    'sap cloud foundry',
#    'sap hana',
#    'sap cloud foundry',
#    'sap hana',
#    'sap hana',
#    'sap hana']],
#  [2422423, ['sap fiori', 'sap fiori', 'sap fiori']],
#  [2552084,
#   ['sap hana cloud platform',
#    'sap business suite',
#    'sap hana cloud platform',
#    'sap hana',
#    'sap hana cloud platform',
#    'sap hana cloud platform',
#    'sap hana cloud platform',
#    'sap hana cloud platform',
#    'sap fiori',
#    'sap fiori',
#    'sap hana cloud platform',
#    'sap fiori',
#    'sap fiori',
#    'sap fiori',
#    'sap hana cloud platform',
#    'sap hana cloud platform',
#    'sap fiori',
#    'sap fiori',
#    'sap fiori',
#    'sap fiori',
#    'sap fiori',
#    'sap hana cloud platform',
#    'sap fiori']],
#  [228631, ['sap hana', 'sap cloud foundry']],
#  [1906580, ['sap fiori', 'sap fiori']],
#  [1677812,
#   ['sap customer relationship management',
#    'sap business warehouse',
#    'sap business warehouse',
#    'sap business warehouse',
#    'sap business warehouse']],
#  [1270482, []],
#  [2496090, ['sap hcm']],
#  [243267,
#   ['sap sybase iq',
#    'sap hana',
#    'sap sybase iq',
#    'sap sybase iq',
#    'sap netweaver',
#    'sap sybase iq',
#    'sap netweaver',
#    'sap sybase iq',
#    'sap sybase iq',
#    'sap sybase iq',
#    'sap sybase iq',
#    'sap sybase iq',
#    'sap sybase iq',
#    'sap business warehouse']],
#  [2326795, ['sap fiori']],
#  [363064, ['sap hana cloud']],
#  [223578, ['sap hana', 'sap cloud platform', 'sap hana']],
#  [390448, ['sap hcm']],
#  [414290, ['sap hana']],
#  [704629, []],
#  [1758514, ['sap hana', 'sap hcm']],
#  [2524556, []],
#  [1814406, []],
#  [1038986, ['sap hana']],
#  [857272, []],
#  [780643, ['sap cloud foundry']],
#  [679881, ['sap gateway', 'sap gateway', 'sap gateway', 'sap gateway']],
#  [1905694, ['sap hana']],
#  [501894,
#   ['sap cloud platform integration',
#    'sap cloud platform integration',
#    'sap cloud platform integration',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud platform integration',
#    'sap cloud foundry',
#    'sap cloud platform integration',
#    'sap cloud foundry',
#    'sap cloud platform integration',
#    'sap cloud platform integration',
#    'sap cloud platform integration',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud platform integration',
#    'sap cloud platform integration',
#    'sap cloud platform integration',
#    'sap cloud platform integration',
#    'sap cloud platform integration',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud platform integration',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud platform integration',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud platform integration',
#    'sap cloud platform integration',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap hana',
#    'sap cloud platform integration',
#    'sap hana',
#    'sap cloud platform integration',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud platform',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud platform integration',
#    'sap cloud platform integration',
#    'sap cloud platform integration',
#    'sap cloud platform integration',
#    'sap cloud foundry',
#    'sap cloud platform integration',
#    'sap cloud platform integration',
#    'sap cloud platform integration',
#    'sap cloud foundry',
#    'sap cloud platform integration',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap hana',
#    'sap hana',
#    'sap cloud foundry',
#    'sap hana',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap hana',
#    'sap hana',
#    'sap cloud foundry',
#    'sap hana',
#    'sap hana',
#    'sap hana',
#    'sap cloud foundry',
#    'sap cloud platform integration',
#    'sap cloud foundry',
#    'sap cloud platform integration',
#    'sap cloud foundry',
#    'sap cloud platform integration',
#    'sap cloud platform integration',
#    'sap cloud foundry',
#    'sap cloud foundry']],
#  [185319, []],
#  [1608202, ['sap cloud platform integration', 'sap hana']],
#  [1880525, ['sap hana', 'sap hana', 'sap hana', 'sap hana']],
#  [2014314,
#   ['sap lumira',
#    'sap lumira',
#    'sap lumira',
#    'sap hana',
#    'sap hana',
#    'sap hana',
#    'sap hana',
#    'sap lumira']],
#  [2084651, ['sap hybris', 'sap hybris', 'sap hybris', 'sap hybris']],
#  [304099,
#   ['sap business objects', 'sap business objects', 'sap business objects']],
#  [2237905, ['sap hana cloud platform']],
#  [1354743, ['sap innovative business solutions']],
#  [1133311, []],
#  [1077629,
#   ['sap hana cloud platform',
#    'sap lumira',
#    'sap lumira',
#    'sap business intelligence']],
#  [1868797, []],
#  [1676969, []],
#  [2584591,
#   ['sap cloud foundry',
#    'sap hana',
#    'sap hana',
#    'sap cloud foundry',
#    'sap hana',
#    'sap cloud foundry',
#    'sap hana',
#    'sap hana',
#    'sap cloud platform',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap hana',
#    'sap cloud foundry',
#    'sap hana',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap hana',
#    'sap hana',
#    'sap cloud foundry',
#    'sap hana']],
#  [464723, ['sap netweaver', 'sap netweaver']],
#  [1413714,
#   ['sap cloud platform',
#    'sap cloud platform',
#    'sap cloud platform',
#    'sap cloud platform',
#    'sap cloud platform']],
#  [1637082, ['sap hana']],
#  [1239564, ['sap customer relationship management']],
#  [304574, ['sap caf']],
#  [2498886,
#   ['sap netweaver',
#    'sap netweaver',
#    'sap netweaver',
#    'sap netweaver',
#    'sap netweaver',
#    'sap icm',
#    'sap icm',
#    'sap netweaver']],
#  [2422558,
#   ['sap gateway', 'sap gateway', 'sap gateway', 'sap gateway', 'sap fiori']],
#  [586396, ['sap hana', 'sap business warehouse', 'sap hana']],
#  [1130714, ['sap cloud foundry', 'sap hana', 'sap cloud foundry']],
#  [692429,
#   ['sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry',
#    'sap cloud foundry']],
#  [2010958, ['sap business warehouse']],
#  [1034974, []],
#  [1871748, ['sap hcm']],
#  [1896666,
#   ['sap hana',
#    'sap sybase iq',
#    'sap hana',
#    'sap hana',
#    'sap hana',
#    'sap hana',
#    'sap hana',
#    'sap hana']],
#  [1933102, []],
#  [319272, ['sap sybase iq']],
#  [413773, []],
#  [522167, []],
#  [206309, ['sap netweaver']],
#  [1559970, []],
#  [456834, ['sap business objects']],
#  [1476754, []],
#  [1883649, ['sap hana cloud platform']],
#  [2526179, ['sap netweaver']],
#  [979324, ['sap cloud platform integration']],
#  [2140164, ['sap hana', 'sap hana', 'sap hana']],
#  [1879723, ['sap hana']],
#  [1913875, []]]

# %% [markdown]
# # SAVE FINAL ID-ENTITIES TO FILE:

# %%
def save_df_to_file(filename, df):
    file_path_to_a = 'ekg_enrichment/'+filename
    df.to_csv(file_path_to_a, sep=',',index=False)

# %%
def save_list_to_csv(filename, listname):

    df = pd.DataFrame(listname)

    save_df_to_file(filename, df)
    
    return print('Data saved to file')

# %%
save_list_to_csv('final_id_entities_1_1000_nodes.csv', final_id_entities)
# Out:
# Data saved to file
